# %%
# !pip install bioservices
# !pip install biomodels
# Out:
# Collecting bioservices
#   Downloading bioservices-1.15.0-py3-none-any.whl.metadata (24 kB)
# Collecting appdirs<2.0.0,>=1.4.4 (from bioservices)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from bioservices) (4.14.3)
# Collecting click<9.0.0,>=8.1.8 (from bioservices)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting colorlog<7.0.0,>=6.9.0 (from bioservices)
#   Using cached colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting easydev<0.14.0,>=0.13.3 (from bioservices)
#   Using cached easydev-0.13.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting grequests<0.8.0,>=0.7.0 (from bioservices)
#   Using cached grequests-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting lxml<6.0.0,>=5.3.0 (from bioservices)
#   Downloading lxml-5.4.0-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Requirement already satisfied: matplotlib>=3.9 in /Users/thalie/.local/lib/python3.12/site-packages (from bioservices) (3.10.1)
# Collecting numpy<2.4,>=1.23.2 (from bioservices)
#   Downloading numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting pandas>2.2 (from bioservices)
#   Downloading pandas-3.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from bioservices) (2.32.5)
# Collecting requests-cache<2.0.0,>=1.2.1 (from bioservices)
#   Using cached requests_cache-1.3.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting rich-click<2.0.0,>=1.8.5 (from bioservices)
#   Using cached rich_click-1.9.7-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from bioservices) (4.67.1)
# Collecting wrapt<2.0.0,>=1.17.2 (from bioservices)
#   Downloading wrapt-1.17.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting xmltodict<0.15.0,>=0.14.2 (from bioservices)
#   Using cached xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->bioservices) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->bioservices) (4.15.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from easydev<0.14.0,>=0.13.3->bioservices) (0.4.6)
# Collecting line-profiler<5.0.0,>=4.1.2 (from easydev<0.14.0,>=0.13.3->bioservices)
#   Downloading line_profiler-4.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (34 kB)
# Requirement already satisfied: pexpect<5.0.0,>=4.9.0 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from easydev<0.14.0,>=0.13.3->bioservices) (4.9.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.2.0 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from easydev<0.14.0,>=0.13.3->bioservices) (4.5.0)
# Collecting gevent (from grequests<0.8.0,>=0.7.0->bioservices)
#   Downloading gevent-25.9.1-cp312-cp312-macosx_11_0_universal2.whl.metadata (14 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from pexpect<5.0.0,>=4.9.0->easydev<0.14.0,>=0.13.3->bioservices) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->bioservices) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->bioservices) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->bioservices) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->bioservices) (2025.11.12)
# Requirement already satisfied: attrs>=21.2 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests-cache<2.0.0,>=1.2.1->bioservices) (26.1.0)
# Collecting cattrs>=22.2 (from requests-cache<2.0.0,>=1.2.1->bioservices)
#   Using cached cattrs-26.1.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting url-normalize>=2.0 (from requests-cache<2.0.0,>=1.2.1->bioservices)
#   Using cached url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting rich>=12 (from rich-click<2.0.0,>=1.8.5->bioservices)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.9->bioservices)
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.9->bioservices)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.9->bioservices)
#   Downloading fonttools-4.62.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.9->bioservices)
#   Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from matplotlib>=3.9->bioservices) (25.0)
# Collecting pillow>=8 (from matplotlib>=3.9->bioservices)
#   Downloading pillow-12.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.9->bioservices)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from matplotlib>=3.9->bioservices) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.9->bioservices) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12->rich-click<2.0.0,>=1.8.5->bioservices)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from rich>=12->rich-click<2.0.0,>=1.8.5->bioservices) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12->rich-click<2.0.0,>=1.8.5->bioservices)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting greenlet>=3.2.2 (from gevent->grequests<0.8.0,>=0.7.0->bioservices)
#   Downloading greenlet-3.3.2-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting zope.event (from gevent->grequests<0.8.0,>=0.7.0->bioservices)
#   Using cached zope_event-6.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting zope.interface (from gevent->grequests<0.8.0,>=0.7.0->bioservices)
#   Downloading zope_interface-8.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (45 kB)
# Downloading bioservices-1.15.0-py3-none-any.whl (274 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached colorlog-6.10.1-py3-none-any.whl (11 kB)
# Using cached easydev-0.13.3-py3-none-any.whl (57 kB)
# Using cached grequests-0.7.0-py2.py3-none-any.whl (5.7 kB)
# Downloading line_profiler-4.2.0-cp312-cp312-macosx_11_0_arm64.whl (134 kB)
# Downloading lxml-5.4.0-cp312-cp312-macosx_10_9_universal2.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 11.7 MB/s  0:00:00 11.5 MB/s eta 0:00:01
# Downloading numpy-2.3.5-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 14.3 MB/s  0:00:00 19.0 MB/s eta 0:00:01
# Using cached requests_cache-1.3.1-py3-none-any.whl (70 kB)
# Using cached rich_click-1.9.7-py3-none-any.whl (71 kB)
# Downloading wrapt-1.17.3-cp312-cp312-macosx_11_0_arm64.whl (39 kB)
# Using cached xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Using cached cattrs-26.1.0-py3-none-any.whl (73 kB)
# Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 14.2 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
# Downloading pandas-3.0.1-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 15.2 MB/s  0:00:00a 0:00:01m eta 0:00:01
# Downloading pillow-12.1.1-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 12.0 MB/s  0:00:00 15.0 MB/s eta 0:00:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Downloading gevent-25.9.1-cp312-cp312-macosx_11_0_universal2.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 15.4 MB/s  0:00:00
# Downloading greenlet-3.3.2-cp312-cp312-macosx_11_0_universal2.whl (280 kB)
# Using cached zope_event-6.1-py3-none-any.whl (6.4 kB)
# Downloading zope_interface-8.2-cp312-cp312-macosx_11_0_arm64.whl (208 kB)
# Installing collected packages: appdirs, zope.interface, zope.event, xmltodict, wrapt, url-normalize, pyparsing, pillow, numpy, mdurl, lxml, line-profiler, kiwisolver, greenlet, fonttools, cycler, colorlog, click, cattrs, requests-cache, pandas, markdown-it-py, gevent, easydev, contourpy, rich, grequests, rich-click, bioservices
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [bioservices]m 25/29 [rich] [easydev]]
# Successfully installed appdirs-1.4.4 bioservices-1.15.0 cattrs-26.1.0 click-8.3.1 colorlog-6.10.1 contourpy-1.3.3 cycler-0.12.1 easydev-0.13.3 fonttools-4.62.1 gevent-25.9.1 greenlet-3.3.2 grequests-0.7.0 kiwisolver-1.5.0 line-profiler-4.2.0 lxml-5.4.0 markdown-it-py-4.0.0 mdurl-0.1.2 numpy-2.3.5 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2 requests-cache-1.3.1 rich-14.3.3 rich-click-1.9.7 url-normalize-2.2.1 wrapt-1.17.3 xmltodict-0.14.2 zope.event-6.1 zope.interface-8.2
# Collecting biomodels
#   Using cached biomodels-0.3.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting pooch (from biomodels)
#   Using cached pooch-1.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting pydantic (from biomodels)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting pydantic-xml (from biomodels)
#   Using cached pydantic_xml-2.19.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tabulate (from biomodels)
#   Using cached tabulate-0.10.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from pooch->biomodels) (4.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from pooch->biomodels) (25.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from pooch->biomodels) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests>=2.19.0->pooch->biomodels) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests>=2.19.0->pooch->biomodels) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests>=2.19.0->pooch->biomodels) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from requests>=2.19.0->pooch->biomodels) (2025.11.12)
# Collecting annotated-types>=0.6.0 (from pydantic->biomodels)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic->biomodels)
#   Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/thalie/miniforge3/lib/python3.12/site-packages (from pydantic->biomodels) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic->biomodels)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Using cached biomodels-0.3.2-py3-none-any.whl (9.1 kB)
# Using cached pooch-1.9.0-py3-none-any.whl (67 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 6.8 MB/s  0:00:00m 4.6 MB/s eta 0:00:01
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached pydantic_xml-2.19.0-py3-none-any.whl (42 kB)
# Using cached tabulate-0.10.0-py3-none-any.whl (39 kB)
# Installing collected packages: typing-inspection, tabulate, pydantic-core, annotated-types, pydantic, pooch, pydantic-xml, biomodels
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [biomodels]━ 4/8 [pydantic]
# Successfully installed annotated-types-0.7.0 biomodels-0.3.2 pooch-1.9.0 pydantic-2.12.5 pydantic-core-2.41.5 pydantic-xml-2.19.0 tabulate-0.10.0 typing-inspection-0.4.2

# %%
import biomodels
from bioservices import BioModels
from pathlib import Path
import shutil

# %%
#récupération des IDs et stockage dans un dictionnaire

disease = ["covid", "dengue", "chikungunya", "Mpox", "west nile", "influenza", "tuberculosis", "lyme", "borrelia", "borreliosis"] #lyme(disease) = borrelia = borreliosis
s = BioModels()
model_ids = {}

for el in disease:
    results = s.search(el)
    model_ids[el] = [res['id'] for res in results.get('models', [])]

print(model_ids)
# Out:
# INFO    [bioservices.BioModels:292]:  Initialising BioModels service (REST)
# {'covid': ['BIOMD0000000970', 'BIOMD0000000969', 'BIOMD0000000982', 'BIOMD0000000957', 'BIOMD0000000976', 'BIOMD0000000978', 'BIOMD0000000958', 'BIOMD0000000977', 'BIOMD0000000991', 'BIOMD0000000962'], 'dengue': ['MODEL2003160002', 'MODEL2003190001', 'MODEL2311070006', 'MODEL2311070001', 'MODEL2311070002', 'MODEL2311070003', 'MODEL2311070004', 'MODEL2311070005', 'MODEL2311070007'], 'chikungunya': [], 'Mpox': ['MODEL2208040001'], 'west nile': [], 'influenza': ['BIOMD0000000463', 'BIOMD0000000708', 'BIOMD0000000709', 'BIOMD0000000712', 'BIOMD0000000546', 'BIOMD0000000710', 'BIOMD0000000529', 'BIOMD0000000528', 'BIOMD0000000851', 'BIOMD0000000711'], 'tuberculosis': ['MODEL1507180021', 'MODEL1507180018', 'BIOMD0000001095', 'MODEL2405210004', 'MODEL2404080003', 'BIOMD0000001046', 'MODEL1911120004', 'MODEL1011090002', 'BIOMD0000000222', 'BIOMD0000000219'], 'lyme': [], 'borrelia': [], 'borreliosis': []}

# %%
metadata = biomodels.get_metadata("BIOMD0000000970")
metadata

print(metadata[11])

#biomodels.get_file("metadata.rdf", model_id="BIOMD0000000528")

# %%
#récupération des fichiers SBML/XML/OMEX (Open Modeling EXchange format)
for d in disease :
    if d in model_ids:
      for el in model_ids[d]:
          try:
              metadata = biomodels.get_metadata(el)
              print(f"Modèle {el} pour {d} récupéré.")
              biomodels.get_file(metadata[0])
          except Exception as e:
                print(f"Erreur sur le modèle {el}: {e}")

# %%
racine_data = Path("/Users/thalie/Desktop/Masters/Bioinformatique/M1/Semestre 2/PTUT/Projet_Niaraki/data/SBML_extraction/BioModels_Data")
racine_data.mkdir(parents=True, exist_ok=True)

s = BioModels()
diseases = ["covid", "dengue", "chikungunya", "Mpox", "west nile", "influenza", "tuberculosis", "lyme", "borrelia", "borreliosis"]

for disease in diseases:
    dossier_maladie = racine_data / disease
    dossier_maladie.mkdir(parents=True, exist_ok=True)

    print(f"\n--- Recherche pour : {disease} ---")
    results = s.search(disease)
    ids = [res['id'] for res in results.get('models', [])]

    for model_id in ids:
        try:
            files_objects = biomodels.get_metadata(model_id)
            if not files_objects:
                continue
            target_file_obj = files_objects[0]
            nom_reel = getattr(target_file_obj, 'name', str(target_file_obj))
            result = biomodels.get_file(target_file_obj)
            dest_path = dossier_maladie / f"{model_id}_{nom_reel}"

            if isinstance(result, (str, Path)) and Path(result).exists():
                shutil.copy(result, dest_path)
                print(f"OK {nom_reel} copié dans /{disease}")
            else:
                with open(dest_path, "w", encoding="utf-8") as f:
                    f.write(str(result))
                print(f"OK {nom_reel} écrit dans /{disease}")

        except Exception as e:
            print(f"Erreur sur {model_id}: {e}")
# Out:
# INFO    [bioservices.BioModels:292]:  Initialising BioModels service (REST)
# --- Recherche pour : covid ---
# OK Hou2020.xml copié dans /covid
# OK Cuadros2020.xml copié dans /covid
# OK Law2020.xml copié dans /covid
# OK Roda2020.xml copié dans /covid
# OK Ghanbari2020.xml copié dans /covid
# OK Mukandavire2020.xml copié dans /covid
# OK Ndairou2020.xml copié dans /covid
# OK Sarkar2020.xml copié dans /covid
# OK Okuonghae2020.xml copié dans /covid
# OK Zhao2020.xml copié dans /covid
#
# --- Recherche pour : dengue ---
# OK Ndii2015.xml copié dans /dengue
# OK Rodrigues2014.xml copié dans /dengue
# OK Dengue.omex copié dans /dengue
# OK SARS-CoV-2_CoreModelsBALF1Epithelial.omex copié dans /dengue
# OK Influenza.omex copié dans /dengue
# OK SARS-CoV-2_CoreModelsIntestine.omex copié dans /dengue
# OK SARS-CoV-2_CoreModelsscH1299.omex copié dans /dengue
# OK SARS-CoV-2_CoreModelsCALU3.omex copié dans /dengue
# OK SARS-CoV-2_CoreModelsBALF2.omex copié dans /dengue
#
# --- Recherche pour : chikungunya ---
#
# --- Recherche pour : Mpox ---
# OK Monkeypox_KG_2ndSep.pkl copié dans /Mpox
#
# --- Recherche pour : west nile ---
#
# --- Recherche pour : influenza ---
# OK BIOMD0000000463_url.xml copié dans /influenza
# OK Liu2017 - Dynamics of Avian Influenza with Logistic Growth.xml copié dans /influenza
# OK Liu2017 - Dynamics of Avian Influenza with Allee Growth Effect.xml copié dans /influenza
# OK Jena5258.xml copié dans /influenza
# OK BIOMD0000000546.xml copié dans /influenza
# OK Hernandez-Vargas2012 - Innate immune system dynamics to Influenza virus.xml copié dans /influenza
# OK BIOMD0000000529_url.xml copié dans /influenza
# OK BIOMD0000000528_url.xml copié dans /influenza
# OK Ho2019.xml copié dans /influenza
# OK Hancioglu2007 - Human Immune Response to Influenza A virus.xml copié dans /influenza
#
# --- Recherche pour : tuberculosis ---
# OK MODEL1507180021_url.xml copié dans /tuberculosis
# OK MODEL1507180018_url.xml copié dans /tuberculosis
# OK MODEL1507180001_url.xml copié dans /tuberculosis
# OK BioModelsMetadata - eos8d8a.csv copié dans /tuberculosis
# OK BioModelsMetadata - eos46ev.csv copié dans /tuberculosis
# OK Raman2005_MAP.xml copié dans /tuberculosis
# OK Gupta2019.xml copié dans /tuberculosis
# OK MODEL1011090002_url.xml copié dans /tuberculosis
# OK BIOMD0000000222_url.xml copié dans /tuberculosis
# OK BIOMD0000000219_url.xml copié dans /tuberculosis
#
# --- Recherche pour : lyme ---
#
# --- Recherche pour : borrelia ---
#
# --- Recherche pour : borreliosis ---

# %%
import biomodels
from bioservices import BioModels
from pathlib import Path
import shutil

# 1. Dossier racine
racine_data = Path("/Users/thalie/Desktop/Masters/Bioinformatique/M1/Semestre 2/PTUT/Projet_Niaraki/data/SBML_extraction/BioModels_Data_DOID")
racine_data.mkdir(parents=True, exist_ok=True)

s = BioModels()

# Dictionnaire de vos DOID (Clé = Nom du dossier, Valeur = l'identifiant DOID)
# Exemple : DOID:0080600 (COVID-19), DOID:12205 (Dengue), etc.
doid_list = {
    "covid": "DOID:0080600",
    "dengue": "DOID:0050125",
    "chikungunya": "DOID:0050012",
    "Mpox": "DOID:3292",
    "west_nile": "DOID:2366",
    "influenza": "DOID:8469"
}

for name, doid in doid_list.items():
    dossier_maladie = racine_data / name
    dossier_maladie.mkdir(parents=True, exist_ok=True)

    print(f"\n--- Recherche pour {name} ({doid}) ---")

    # Recherche spécifique par DOID
    results = s.search(f"id:{doid}")
    ids = [res['id'] for res in results.get('models', [])]

    if not ids:
        print(f"  Aucun modèle trouvé pour le DOID {doid}")
        continue

    for model_id in ids:
        try:
            files_objects = biomodels.get_metadata(model_id)
            if not files_objects:
                continue

            target_file_obj = files_objects[0]
            # Extraction sécurisée du nom de fichier
            nom_reel = getattr(target_file_obj, 'name', str(target_file_obj))

            result = biomodels.get_file(target_file_obj)
            dest_path = dossier_maladie / f"{model_id}_{nom_reel}"

            if isinstance(result, (str, Path)) and Path(result).exists():
                shutil.copy(result, dest_path)
            else:
                with open(dest_path, "w", encoding="utf-8") as f:
                    f.write(str(result))

            print(f"  {nom_reel} enregistré.")

        except Exception as e:
            print(f"  Erreur sur {model_id}: {e}")
# Out:
# INFO    [bioservices.BioModels:292]:  Initialising BioModels service (REST)
# --- Recherche pour covid (DOID:0080600) ---
#   Aucun modèle trouvé pour le DOID DOID:0080600
#
# --- Recherche pour dengue (DOID:0050125) ---
#   Aucun modèle trouvé pour le DOID DOID:0050125
#
# --- Recherche pour chikungunya (DOID:0050012) ---
#   Aucun modèle trouvé pour le DOID DOID:0050012
#
# --- Recherche pour Mpox (DOID:3292) ---
#   Aucun modèle trouvé pour le DOID DOID:3292
#
# --- Recherche pour west_nile (DOID:2366) ---
#   Aucun modèle trouvé pour le DOID DOID:2366
#
# --- Recherche pour influenza (DOID:8469) ---
#   Aucun modèle trouvé pour le DOID DOID:8469
